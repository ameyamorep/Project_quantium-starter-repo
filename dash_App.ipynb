# %%
from dash import Dash, html, doc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dash import Dash, html, doc
#
# ModuleNotFoundError: No module named 'dash'
