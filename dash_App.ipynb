# %%
from dash import Dash, html, dcc
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r'C:\Users\think\Downloads\Ameya UTS Masters\Projects\Project_quantium-starter-repo\data\merged_processed_data.csv')

# %%
app = Dash()

# %%
fig = px.line(df, x = 'date', y = 'sales', title='Sales over time')

app.layout = html.Div(children=[html.H1(children='Sales Dashboard'), 
                                html.Div(children='''Dash: A web app for Sales Visualisation'''),
                                dcc.Graph(id='sales-graph_1', figure=fig)])

# %%
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df_2 = pd.read_csv('data\\merged_quantity_data.csv')
app_2 = Dash()

# %%
fig = px.line(df_2, x = 'date', y = 'quantity', title='Quantity sold over time')

app_2.layout = html.Div(children=[html.H1(children='Quantity Dashboard'), 
                                   html.Div(children='''Dash: A web app for Quantity sold Visualisation'''),
                                   dcc.Graph(id='Quantity-graph_1', figure=fig)])

# %%
if __name__ == '__main__':
    app_2.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h3> Now improving the dashboard by adding 5 radio buttons

# %%
from dash import dcc, html, Input, Output, callback
import plotly.express as px
import pandas as pd

# %%
app_3 = Dash()

# %%
df_3 = pd.read_csv(r'data\merged_processed_data.csv')

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd

app_3 = Dash(__name__)
df_3 = pd.read_csv(r'data\merged_processed_data.csv')

app_3.layout = html.Div([
    html.H1("Regional Sales Dashboard"),
    dcc.RadioItems(
        id='region-radio',
        options=['all', 'north', 'south', 'east', 'west'],
        value='all'
    ),
    dcc.Graph(id='region-graph')
])

@app_3.callback(Output('region-graph', 'figure'), Input('region-radio', 'value'))
def update(region):
    df = df_3 if region == 'all' else df_3[df_3['region'] == region]
    return px.line(df, x='date', y='sales', color='region' if region == 'all' else None,
                   title=f'Sales - {region}')

app_3.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
